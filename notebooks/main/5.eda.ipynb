# %%
import pandas as pd
# %matplotlib inline

train = pd.read_csv("../../data/interim/train.csv")

train.head()
# Out:
#          v1        v2        v3        v4        v5        v6        v7  \
# 0 -0.801242  0.863213  2.262153  0.163269  0.439699  0.099186  0.509842
# 1  1.888375  0.302642 -0.461681  3.715281  0.564265  1.193742 -0.297232
# 2 -0.175369  1.230420 -1.154765 -0.848643  1.160763  0.012115  0.541704
# 3 -1.133432  0.858143  1.516667 -1.288041 -0.176508 -1.067050  0.743314
# 4 -1.592785 -0.452254  1.289814 -4.452088 -1.024463 -1.141025  0.068764
#
#          v8        v9       v10   ...         v21       v22       v23  \
# 0 -1.457983 -1.114560  1.121855   ...    0.172138 -0.919713 -0.294969
# 1  0.249037 -0.585925  1.436384   ...    0.107427  0.559454  0.040160
# 2  0.498493 -0.480224 -0.905377   ...   -0.303549 -0.876726  0.024580
# 3 -0.152737  0.109759 -0.344643   ...   -0.106558 -0.123656  0.049412
# 4  0.320863  0.252155 -1.962361   ...   -0.202288 -0.366467 -0.060495
#
#         v24       v25       v26       v27       v28  amount  target
# ...

# %%
train.describe()
# Out:
#                   v1             v2             v3             v4  \
# count  244934.000000  244934.000000  244934.000000  244934.000000
# mean        0.000712      -0.000784       0.001161      -0.000785
# std         1.954541       1.644781       1.517134       1.415044
# min       -56.407510     -72.715728     -48.325589      -5.683171
# 25%        -0.920096      -0.599536      -0.888978      -0.848139
# 50%         0.019042       0.065422       0.180523      -0.021379
# 75%         1.314955       0.803852       1.029430       0.742548
# max         2.454930      22.057729       9.382558      16.715537
#
#                   v5             v6             v7             v8  \
# count  244934.000000  244934.000000  244934.000000  244934.000000
# mean       -0.000616       0.000793      -0.000023       0.000618
# std         1.381138       1.333166       1.240209       1.195255
# min      -113.743307     -26.160506     -43.557242     -73.216718
# ...

# %%
train['v1'].hist()

# %%
train.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11bd1d860>,
# ...
#       dtype=object)
